# %% [markdown]
# ## MLFLOW tracking Server

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5000")

# %%
mlflow.set_tracking_uri("Check LocalHost Connection")

with mlflow.start_run():
    mlflow.log_metric("Test",1)
    mlflow.log_metric("Adarsh",2)

# %%
with mlflow.start_run():
    mlflow.log_metric("Adarshkr",5)
    mlflow.log_metric("tanmay",21)

# %%
with mlflow.start_run():
    mlflow.log_metric("accuracy", 0.95)

# %%
import mlflow
print(mlflow.get_tracking_uri())
# Out:
# Check LocalHost Connection

# %%
mlflow.set_tracking_uri("file:///Users/adarshkumar/Developer/mlops/MLflow/mlruns")

# %%
with mlflow.start_run(run_name="test"):
    mlflow.log_metric("test_metric", 5)
# Out:
# /opt/anaconda3/envs/mlflow-env/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/utils.py:140: FutureWarning: Filesystem tracking backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri, store_uri)
